# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import zipfile
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
import shutil

# Paths and extraction (your code unchanged)
zip_path = "Dataset not included — withheld pending publication"
extract_target_dir = "Dataset not included — withheld pending publication"

if os.path.exists(extract_target_dir):
    shutil.rmtree(extract_target_dir)
os.makedirs(extract_target_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_target_dir)

# Handle nested folder (your code)
actual_dataset_root = extract_target_dir
sub_dirs = [d for d in os.listdir(extract_target_dir) if os.path.isdir(os.path.join(extract_target_dir, d))]
if len(sub_dirs) == 1:
    actual_dataset_root = os.path.join(extract_target_dir, sub_dirs[0])

# Fix folder names
import os
val_old = os.path.join(actual_dataset_root, 'Validation')
val_new = os.path.join(actual_dataset_root, 'validation')
if os.path.exists(val_old): os.rename(val_old, val_new)

for folder in ['train', 'validation']:
    normal_old = os.path.join(actual_dataset_root, folder, 'normal')
    normal_new = os.path.join(actual_dataset_root, folder, 'Normal')
    if os.path.exists(normal_old): os.rename(normal_old, normal_new)

# Settings (your code)
train_dir = os.path.join(actual_dataset_root, "train")
val_dir = os.path.join(actual_dataset_root, "validation")
IMG_SIZE = (100, 100)
BATCH_SIZE = 32
EPOCHS = 30

# Data generators - NO AUGMENTATION (your pre-augmented data)
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', classes=['High', 'Low', 'Normal'], shuffle=True)

val_data = val_datagen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', classes=['High', 'Low', 'Normal'], shuffle=False)

# CLASS WEIGHTS (ONLY NEW ADDITION)
class_weights = class_weight.compute_class_weight(
    'balanced', classes=np.unique(train_data.classes), y=train_data.classes)
class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)

# Your exact CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train with class weights
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    class_weight=class_weights  # KEY FIX
)

# Save and plot (your code)
model.save("Dataset not included — withheld pending publication")

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title("Accuracy"); plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title("Loss"); plt.legend()
plt.show()

# Confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

val_data.reset()
y_pred = model.predict(val_data)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_data.classes

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['High','Low','Normal'],
            yticklabels=['High','Low','Normal'])
plt.title('Confusion Matrix'); plt.ylabel('True'); plt.xlabel('Predicted')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 1373 images belonging to 3 classes.
# Found 129 images belonging to 3 classes.
# Class weights: {0: np.float64(1.2075637642919965), 1: np.float64(1.1081517352703794), 2: np.float64(0.7877223178427998)}
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,732,163 (6.61 MB)
#  Trainable params: 1,732,163 (6.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 42s 846ms/step - accuracy: 0.4827 - loss: 0.9582 - val_accuracy: 0.8682 - val_loss: 0.6126
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 32s 652ms/step - accuracy: 0.8033 - loss: 0.5224 - val_accuracy: 0.8450 - val_loss: 0.5371
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 627ms/step - accuracy: 0.8412 - loss: 0.4370 - val_accuracy: 0.7674 - val_loss: 0.6016
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 41s 634ms/step - accuracy: 0.8491 - loss: 0.4096 - val_accuracy: 0.9070 - val_loss: 0.4164
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 641ms/step - accuracy: 0.8723 - loss: 0.3690 - val_accuracy: 0.7597 - val_loss: 0.5670
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 643ms/step - accuracy: 0.8773 - loss: 0.3302 - val_accuracy: 0.8527 - val_loss: 0.4200
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 678ms/step - accuracy: 0.8961 - loss: 0.2913 - val_accuracy: 0.6589 - val_loss: 0.8230
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 681ms/step - accuracy: 0.8697 - loss: 0.3157 - val_accuracy: 0.8140 - val_loss: 0.5106
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 668ms/step - accuracy: 0.8873 - loss: 0.3048 - val_accuracy: 0.8527 - val_loss: 0.3067
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 668ms/step - accuracy: 0.9279 - loss: 0.1952 - val_accuracy: 0.8992 - val_loss: 0.2589
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 647ms/step - accuracy: 0.9230 - loss: 0.2245 - val_accuracy: 0.8140 - val_loss: 0.3739
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 646ms/step - accuracy: 0.9558 - loss: 0.1394 - val_accuracy: 0.8372 - val_loss: 0.4266
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 618ms/step - accuracy: 0.9193 - loss: 0.2525 - val_accuracy: 0.7829 - val_loss: 0.5096
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 612ms/step - accuracy: 0.9538 - loss: 0.1304 - val_accuracy: 0.8915 - val_loss: 0.2835
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 647ms/step - accuracy: 0.9488 - loss: 0.1149 - val_accuracy: 0.7132 - val_loss: 1.1282
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 638ms/step - accuracy: 0.8542 - loss: 0.5415 - val_accuracy: 0.7442 - val_loss: 0.5729
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 640ms/step - accuracy: 0.9377 - loss: 0.1775 - val_accuracy: 0.8837 - val_loss: 0.2857
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 644ms/step - accuracy: 0.9503 - loss: 0.1328 - val_accuracy: 0.8605 - val_loss: 0.3736
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 26s 601ms/step - accuracy: 0.9654 - loss: 0.0895 - val_accuracy: 0.8760 - val_loss: 0.6480
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 626ms/step - accuracy: 0.9204 - loss: 0.2494 - val_accuracy: 0.8605 - val_loss: 0.4237
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 639ms/step - accuracy: 0.9301 - loss: 0.1793 - val_accuracy: 0.7287 - val_loss: 0.7162
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 644ms/step - accuracy: 0.9775 - loss: 0.0956 - val_accuracy: 0.8992 - val_loss: 0.3842
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 650ms/step - accuracy: 0.9641 - loss: 0.0781 - val_accuracy: 0.8682 - val_loss: 0.5563
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 682ms/step - accuracy: 0.9736 - loss: 0.0588 - val_accuracy: 0.7907 - val_loss: 0.4155
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 33s 760ms/step - accuracy: 0.9804 - loss: 0.0650 - val_accuracy: 0.7597 - val_loss: 0.9921
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 681ms/step - accuracy: 0.9675 - loss: 0.0828 - val_accuracy: 0.8682 - val_loss: 0.5095
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 31s 727ms/step - accuracy: 0.9848 - loss: 0.0446 - val_accuracy: 0.7907 - val_loss: 0.5021
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 642ms/step - accuracy: 0.9551 - loss: 0.1269 - val_accuracy: 0.7829 - val_loss: 0.5260
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 27s 619ms/step - accuracy: 0.9791 - loss: 0.0607 - val_accuracy: 0.8682 - val_loss: 0.5906
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 648ms/step - accuracy: 0.9700 - loss: 0.0764 - val_accuracy: 0.8682 - val_loss: 0.4776
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b41a3a2b600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b41a3a2b600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step
